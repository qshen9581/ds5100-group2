# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("data_all.csv")
data.head(4)
# Out:
#    Unnamed: 0      Country          Region  Happiness Rank  Happiness Score  \
# 0           0  Switzerland  Western Europe               1            7.587
# 1           1      Iceland  Western Europe               2            7.561
# 2           2      Denmark  Western Europe               3            7.527
# 3           3       Norway  Western Europe               4            7.522
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
#
#    Generosity  Dystopia Residual  Year  Lower Confidence Interval  \
# 0     0.29678            2.51738  2015                        NaN
# 1     0.43630            2.70201  2015                        NaN
# 2     0.34139            2.49204  2015                        NaN
# 3     0.34699            2.46531  2015                        NaN
#
#    Upper Confidence Interval  Whisker.high  Whisker.low
# 0                        NaN           NaN          NaN
# 1                        NaN           NaN          NaN
# 2                        NaN           NaN          NaN
# 3                        NaN           NaN          NaN

# %%
Y_2015=data[data["Year"]==2015]
Y_2016=data[data["Year"]==2016]
Y_2017=data[data["Year"]==2017]
Y_2018=data[data["Year"]==2018]
Y_2019=data[data["Year"]==2019]

# %%
plt.hist(Y_2015["Happiness Score"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(Y_2016["Happiness Score"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(Y_2017["Happiness Score"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(Y_2018["Happiness Score"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(Y_2019["Happiness Score"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.groupby("Year")["Happiness Score"].mean()
# Out:
# Year
# 2015    5.375734
# 2016    5.382185
# 2017    5.354019
# 2018    5.375917
# 2019    5.407096
# Name: Happiness Score, dtype: float64

# %%
data_top = data[data["Happiness Rank"]<=5]
data_top
# Out:
#      Unnamed: 0      Country          Region  Happiness Rank  Happiness Score  \
# 0             0  Switzerland  Western Europe               1            7.587
# 1             1      Iceland  Western Europe               2            7.561
# 2             2      Denmark  Western Europe               3            7.527
# 3             3       Norway  Western Europe               4            7.522
# 4             4       Canada   North America               5            7.427
# 158         158      Denmark  Western Europe               1            7.526
# 159         159  Switzerland  Western Europe               2            7.509
# 160         160      Iceland  Western Europe               3            7.501
# 161         161       Norway  Western Europe               4            7.498
# 162         162      Finland  Western Europe               5            7.413
# 315         315       Norway             NaN               1            7.537
# 316         316      Denmark             NaN               2            7.522
# 317         317      Iceland             NaN               3            7.504
# 318         318  Switzerland             NaN               4            7.494
# 319         319      Finland             NaN               5            7.469
# 470         470      Finland             NaN               1            7.632
# 471         471       Norway             NaN               2            7.594
# 472         472      Denmark             NaN               3            7.555
# 473         473      Iceland             NaN               4            7.495
# 474         474  Switzerland             NaN               5            7.487
# 626         626      Finland             NaN               1            7.769
# 627         627      Denmark             NaN               2            7.600
# 628         628       Norway             NaN               3            7.554
# 629         629      Iceland             NaN               4            7.494
# 630         630  Netherlands             NaN               5            7.488
#
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0           0.03411                  1.396510  1.349510
# 1           0.04884                  1.302320  1.402230
# 2           0.03328                  1.325480  1.360580
# 472    0.284000                NaN  2018                        NaN
# 473    0.353000                NaN  2018                        NaN
# 474    0.256000                NaN  2018                        NaN
# 626    0.153000                NaN  2019                        NaN
# 627    0.252000                NaN  2019                        NaN
# 628    0.271000                NaN  2019                        NaN
# 629    0.354000                NaN  2019                        NaN
# 630    0.322000                NaN  2019                        NaN
#
#      Upper Confidence Interval  Whisker.high  Whisker.low
# 0                          NaN           NaN          NaN
# 1                          NaN           NaN          NaN
# 2                          NaN           NaN          NaN
# 3                          NaN           NaN          NaN
# 4                          NaN           NaN          NaN
# 158                      7.592           NaN          NaN
# 159                      7.590           NaN          NaN
# 160                      7.669           NaN          NaN
# 161                      7.575           NaN          NaN
# 162                      7.475           NaN          NaN
# 315                        NaN      7.594445     7.479556
# 316                        NaN      7.581728     7.462272
# 317                        NaN      7.622030     7.385970
# 318                        NaN      7.561772     7.426227
# 319                        NaN      7.527542     7.410458
# 470                        NaN           NaN          NaN
# 471                        NaN           NaN          NaN
# 472                        NaN           NaN          NaN
# 473                        NaN           NaN          NaN
# 474                        NaN           NaN          NaN
# 626                        NaN           NaN          NaN
# 627                        NaN           NaN          NaN
# 628                        NaN           NaN          NaN
# 629                        NaN           NaN          NaN
# 630                        NaN           NaN          NaN

# %%
data_america = data[data["Country"]=="United States"]
data_america
# Out:
#      Unnamed: 0        Country         Region  Happiness Rank  \
# 14           14  United States  North America              15
# 170         170  United States  North America              13
# 328         328  United States            NaN              14
# 487         487  United States            NaN              18
# 644         644  United States            NaN              19
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)    Family  \
# 14             7.119         0.03839                  1.394510  1.247110
# 170            7.104             NaN                  1.507960  1.047820
# 328            6.993             NaN                  1.546259  1.419921
# 487            6.886             NaN                  1.398000  1.471000
# 644            6.892             NaN                  1.433000  1.457000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 14                   0.861790  0.546040                       0.158900
# 170                  0.779000  0.481630                       0.148680
# 328                  0.774287  0.505741                       0.135639
# 487                  0.819000  0.547000                       0.133000
# 644                  0.874000  0.454000                       0.128000
#
#      Generosity  Dystopia Residual  Year  Lower Confidence Interval  \
# 14     0.401050           2.510110  2015                        NaN
# 170    0.410770           2.727820  2016                       7.02
# 328    0.392579           2.218113  2017                        NaN
# 487    0.291000                NaN  2018                        NaN
# 644    0.280000                NaN  2019                        NaN
#
#      Upper Confidence Interval  Whisker.high  Whisker.low
# 14                         NaN           NaN          NaN
# 170                      7.188           NaN          NaN
# 328                        NaN      7.074657     6.911343
# 487                        NaN           NaN          NaN
# 644                        NaN           NaN          NaN

# %%
x = data_america['Year']
y = data_america['Happiness Rank']
plt.bar(x, y, color ='maroon',
        width = 0.4)
 
plt.xlabel("Year")
plt.ylabel("Hapiness Rank")
plt.title("America Happiness Score")
plt.show()
