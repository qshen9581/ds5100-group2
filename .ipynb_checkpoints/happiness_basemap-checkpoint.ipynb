# %% [markdown]
# ### Setup
# A yaml file is provided to create a conda environment to run this notebook.
# To create the env run the following command: conda env create -f ./data/env/environment.yml

# %%
import os
import geopandas as gpd
import pandas as pd
import numpy as np
import pycountry
import plotly.express as px

# %%
df = pd.read_csv('./data/data_all.csv')
df.drop(df.columns[0], axis=1, inplace=True)
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual  Year  Lower Confidence Interval  \
# 0     0.29678            2.51738  2015                        NaN
# 1     0.43630            2.70201  2015                        NaN
# 2     0.34139            2.49204  2015                        NaN
# 3     0.34699            2.46531  2015                        NaN
# 4     0.45811            2.45176  2015                        NaN
#
#    Upper Confidence Interval  Whisker.high  Whisker.low
# 0                        NaN           NaN          NaN
# 1                        NaN           NaN          NaN
# 2                        NaN           NaN          NaN
# 3                        NaN           NaN          NaN
# 4                        NaN           NaN          NaN

# %%
input_countries = df['Country']

countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_3

codes = [countries.get(country, np.nan) for country in input_countries]

df['Country Code'] = codes

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual  Year  Lower Confidence Interval  \
# 0     0.29678            2.51738  2015                        NaN
# 1     0.43630            2.70201  2015                        NaN
# 2     0.34139            2.49204  2015                        NaN
# 3     0.34699            2.46531  2015                        NaN
# 4     0.45811            2.45176  2015                        NaN
#
#    Upper Confidence Interval  Whisker.high  Whisker.low Country Code
# 0                        NaN           NaN          NaN          CHE
# 1                        NaN           NaN          NaN          ISL
# 2                        NaN           NaN          NaN          DNK
# 3                        NaN           NaN          NaN          NOR
# 4                        NaN           NaN          NaN          CAN

# %%
shapefile = r'C:\Users\mkbau\OneDrive\Documents\GitHub\ds5100-group2\data\ne_10m_admin_0_countries\ne_10m_admin_0_countries.shp'
gdf = gpd.read_file(shapefile)[['ADM0_A3', 'geometry']].to_crs('+proj=robin')
print(len(gdf))
gdf.head()
# Out:
# 258
#   ADM0_A3                                           geometry
# 0     IDN  MULTIPOLYGON (((11108970.260 445285.130, 11108...
# 1     MYS  MULTIPOLYGON (((11108970.260 445285.130, 11108...
# 2     CHL  MULTIPOLYGON (((-6477059.899 -1872360.838, -64...
# 3     BOL  POLYGON ((-6477059.899 -1872360.838, -6477072....
# 4     PER  MULTIPOLYGON (((-6477059.899 -1872360.838, -64...

# %%
merged = gdf.merge(df, left_on='ADM0_A3', right_on='Country Code', how='left')
print(len(merged))
merged.head()
# Out:
# 793
#   ADM0_A3                                           geometry    Country  \
# 0     IDN  MULTIPOLYGON (((11108970.260 445285.130, 11108...  Indonesia
# 1     IDN  MULTIPOLYGON (((11108970.260 445285.130, 11108...  Indonesia
# 2     IDN  MULTIPOLYGON (((11108970.260 445285.130, 11108...  Indonesia
# 3     IDN  MULTIPOLYGON (((11108970.260 445285.130, 11108...  Indonesia
# 4     IDN  MULTIPOLYGON (((11108970.260 445285.130, 11108...  Indonesia
#
#               Region  Happiness Rank  Happiness Score  Standard Error  \
# 0  Southeastern Asia            74.0            5.399         0.02596
# 1  Southeastern Asia            79.0            5.314             NaN
# 2                NaN            81.0            5.262             NaN
# 3                NaN            96.0            5.093             NaN
# 4                NaN            92.0            5.192             NaN
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  0.828270  1.087080                  0.637930  0.466110
# 1                  0.951040  0.876250                  0.493740  0.392370
# 2                  0.995539  1.274445                  0.492346  0.443323
# 3                  0.899000  1.215000                  0.522000  0.538000
# 4                  0.931000  1.203000                  0.660000  0.491000
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual    Year  \
# 0                       0.000000    0.515350           1.863990  2015.0
# 1                       0.003220    0.565210           2.031710  2016.0
# 2                       0.015317    0.611705           1.429477  2017.0
# 3                       0.018000    0.484000                NaN  2018.0
# 4                       0.028000    0.498000                NaN  2019.0
#
#    Lower Confidence Interval  Upper Confidence Interval  Whisker.high  \
# 0                        NaN                        NaN           NaN
# 1                      5.237                      5.391           NaN
# 2                        NaN                        NaN      5.352889
# 3                        NaN                        NaN           NaN
# 4                        NaN                        NaN           NaN
#
#    Whisker.low Country Code
# 0          NaN          IDN
# 1          NaN          IDN
# 2     5.171112          IDN
# 3          NaN          IDN
# 4          NaN          IDN

# %%
colors = 9
cmap = 'Oranges'
figsize = (16, 10)
val = 'Happiness Score'
title = '{}'.format(val)
description = '''Happiness Score by Country'''.strip()

# %%
ax = merged.plot(column=val, 
                 cmap=cmap, 
                 figsize=figsize, 
                 scheme='equal_interval', 
                 k=colors, 
                 legend=True,
                 missing_kwds={
                    "color": "lightgrey",
                    "edgecolor": "red",
                    "hatch": "///",
                    "label": "Missing values"})

ax.set_title(title, fontdict={'fontsize': 20}, loc='left')
ax.annotate(description, xy=(0.1, 0.1), size=12, xycoords='figure fraction')

ax.set_axis_off()
ax.set_xlim([-1.5e7, 1.7e7])
ax.get_legend().set_bbox_to_anchor((.12, .4))
