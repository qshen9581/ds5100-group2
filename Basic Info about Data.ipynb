# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data_all.csv")

# %%
data.head()
# Out:
#    Unnamed: 0      Country          Region  Happiness Rank  Happiness Score  \
# 0           0  Switzerland  Western Europe               1            7.587
# 1           1      Iceland  Western Europe               2            7.561
# 2           2      Denmark  Western Europe               3            7.527
# 3           3       Norway  Western Europe               4            7.522
# 4           4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# ...

# %% [markdown]
# # The code below is just finding the mean for each category (to help find a baseline) as well as the stats year by year

# %%
data.groupby(['Year']).mean()
# Out:
#       Unnamed: 0  Happiness Rank  Happiness Score  Standard Error  \
# Year
# 2015        78.5       79.493671         5.375734        0.047885
# 2016       236.0       78.980892         5.382185             NaN
# 2017       392.0       78.000000         5.354019             NaN
# 2018       547.5       78.500000         5.375917             NaN
# 2019       703.5       78.500000         5.407096             NaN
#
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# Year
# 2015                  0.846137  0.991046                  0.630259  0.428615
# 2016                  0.953880  0.793621                  0.557619  0.370994
# 2017                  0.984718  1.188898                  0.551341  0.408786
# 2018                  0.891449  1.213237                  0.597346  0.454506
# 2019                  0.905147  1.208814                  0.725244  0.392571
#
#       Trust (Government Corruption)  Generosity  Dystopia Residual  \
# Year
# ...

# %%
data['Happiness Score'].mean()
# Out:
# 5.379017902998665

# %%
data['Economy (GDP per Capita)'].mean()
# Out:
# 0.9160474824829727

# %%
data['Family'].mean()
# Out:
# 1.0783924825069782

# %%
data['Health (Life Expectancy)'].mean()
# Out:
# 0.6124155771162532

# %%
data['Freedom'].mean()
# Out:
# 0.41109082582231493

# %%
data['Trust (Government Corruption)'].mean()
# Out:
# 0.1254356135735872

# %%
data['Generosity'].mean()
# Out:
# 0.2185758415608299

# %% [markdown]
# # The code below shows a scatterplot comparing each of the 6 components with the happiness score (region being the color) to help show where each region ranks and what they are strong/weak in

# %%
sns.scatterplot(data=data, x="Economy (GDP per Capita)", y="Happiness Score", hue = "Region")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %%
sns.scatterplot(data=data, x="Family", y="Happiness Score", hue="Region")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %%
sns.scatterplot(data=data, x="Health (Life Expectancy)", y="Happiness Score", hue="Region")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %%
sns.scatterplot(data=data, x="Freedom", y="Happiness Score", hue="Region")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %%
sns.scatterplot(data=data, x="Trust (Government Corruption)", y="Happiness Score", hue="Region")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %%
sns.scatterplot(data=data, x="Generosity", y="Happiness Score", hue="Region")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
