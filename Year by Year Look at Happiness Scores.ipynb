# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
data = pd.read_csv("/Users/cavaningram/Downloads/data_all.csv")

# %%
data
# Out:
#       Unnamed: 0      Country                        Region  Happiness Rank  \
# 0              0  Switzerland                Western Europe               1
# 1              1      Iceland                Western Europe               2
# 2              2      Denmark                Western Europe               3
# 3              3       Norway                Western Europe               4
# 4              4       Canada                 North America               5
# ...          ...          ...                           ...             ...
# 1225        1225    Botswana*            Sub-Saharan Africa             142
# 1226        1226      Rwanda*            Sub-Saharan Africa             143
# 1227        1227     Zimbabwe            Sub-Saharan Africa             144
# 1228        1228      Lebanon  Middle East and North Africa             145
# 1229        1229  Afghanistan                    South Asia             146
#
# ...

# %% [markdown]
# # The code below is just finding the mean/median for each category (to help find a baseline) as well as the stats year by year

# %%
data.groupby(['Year']).mean()
# Out:
#       Unnamed: 0  Happiness Rank  Happiness Score  Standard Error  \
# Year
# 2015        78.5       79.493671         5.375734        0.047885
# 2016       236.0       78.980892         5.382185             NaN
# 2017       392.0       78.000000         5.354019             NaN
# 2018       547.5       78.500000         5.375917             NaN
# 2019       703.5       78.500000         5.407096             NaN
# 2020       858.0       77.000000         5.473240             NaN
# 2021      1009.0       75.000000         5.532839             NaN
# 2022      1156.5       73.500000         5.553575             NaN
#
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# Year
# 2015                  0.846137  0.991046                  0.630259  0.428615
# 2016                  0.953880  0.793621                  0.557619  0.370994
# 2017                  0.984718  1.188898                  0.551341  0.408786
# ...

# %%
data_by_year = pd.DataFrame(data.groupby(['Year']).median())
data_by_year
# Out:
#       Unnamed: 0  Happiness Rank  Happiness Score  Standard Error  \
# Year
# 2015        78.5            79.5           5.2325         0.04394
# 2016       236.0            79.0           5.3140             NaN
# 2017       392.0            78.0           5.2790             NaN
# 2018       547.5            78.5           5.3780             NaN
# 2019       703.5            78.5           5.3795             NaN
# 2020       858.0            77.0           5.5150             NaN
# 2021      1009.0            75.0           5.5340             NaN
# 2022      1156.5            73.5           5.5685             NaN
#
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# Year
# 2015                  0.910245  1.029510                  0.696705  0.435515
# 2016                  1.027800  0.841420                  0.596590  0.397470
# 2017                  1.064578  1.253918                  0.606042  0.437454
# ...

# %% [markdown]
# # The code below shows a scatterplot comparing each of the 6 components with the happiness score (region being the color) to help show where each region ranks and what they are strong/weak in

# %%
data["Years"] = data["Year"]
data2 = [data["Year"], data["Years"], data["Economy (GDP per Capita)"],data["Family"], data["Freedom"], data["Health (Life Expectancy)"], data["Trust (Government Corruption)"], data["Generosity"]]
headers = ["Year","Years", "Economy (GDP per Capita)", "Family","Freedom", "Health (Life Expectancy)", "Trust (Government Corruption)", "Generosity" ]
data3 = pd.concat(data2, axis=1, keys=headers)
data4 = data3.groupby(['Year']).mean()
data4 = data4.astype({"Years": int})

# %%
df2 = pd.DataFrame([[2,3,4]], columns=['A','B','C'])

# %%
data5 = [data["Year"], data["Years"],data["Happiness Score"]]
headers2 = ["Year", "Years", "Happiness Score"]
data6=pd.concat(data5, axis=1, keys=headers2)
data7= data6.groupby(['Year']).mean()
data7 = data7.astype({"Years": int})
data7
# Out:
#       Years  Happiness Score
# Year
# 2015   2015         5.375734
# 2016   2016         5.382185
# 2017   2017         5.354019
# 2018   2018         5.375917
# 2019   2019         5.407096
# 2020   2020         5.473240
# 2021   2021         5.532839
# 2022   2022         5.553575

# %%
data4.plot(x='Years',
        kind='bar',
        figsize=(20,5),
        stacked=False,
        title='Grouped Bar Graph of Scores by Year')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
#hard to interpret, but shows scores by each year for each score

# %%
low = min(data7['Happiness Score'])-.01
high = max(data7['Happiness Score'])+.01
plt.ylim(low, high)
plt.bar(data7["Years"],data7['Happiness Score'])
plt.title('Happiness Score by Year')
plt.show() 
#shows steady upward trend (other than 2017) for each year

# %%
low = min(data4['Economy (GDP per Capita)'])-.01
high = max(data4['Economy (GDP per Capita)'])+.01
plt.ylim(low, high)
plt.bar(data7["Years"],data4['Economy (GDP per Capita)'])
plt.title('Economy (GDP per Capita) Score by Year')
plt.show() 
#skyrockets in 2022 but other than that no real trend

# %%
low = min(data4['Family'])-.01
high = max(data4['Family'])+.01
plt.ylim(low, high)
plt.bar(data7["Years"],data4['Family'])
plt.title('Family Score by Year')
plt.show() 
#very low in 2016 and 2021 (very high 2017 to 2020)

# %%
low = min(data4['Freedom'])-.01
high = max(data4['Freedom'])+.01
plt.ylim(low, high)
plt.bar(data7["Years"],data4['Freedom'])
plt.title('Freedom Score by Year')
plt.show() 
#shows upward trend, but 2016 and 2019 are outliers

# %%
low = min(data4['Health (Life Expectancy)'])-.01
high = max(data4['Health (Life Expectancy)'])+.01
plt.ylim(low, high)
plt.bar(data7["Years"],data4['Health (Life Expectancy)'])
plt.title('Health (Life Expectancy) Score by Year')
plt.show() 
#no real trend, but 2019 and 2020 were high

# %%
low = min(data4['Trust (Government Corruption)'])-.01
high = max(data4['Trust (Government Corruption)'])+.01
plt.ylim(low, high)
plt.bar(data7["Years"],data4['Trust (Government Corruption)'])
plt.title('Trust (Government Corruption) Score by Year')
plt.show() 
#parabola shaped where lowest in 2018 and 2019 and highest 2015 and 2022

# %%
low = min(data4['Generosity'])-.01
high = max(data4['Generosity'])+.01
plt.ylim(low, high)
plt.bar(data7["Years"],data4['Generosity'])
plt.title('Generosity Score by Year')
plt.show() 
#shop decrease after 2017 and very low 2022

# %% [markdown]
# # The information below is just general information that might help aid in the analysis for our project

# %% [markdown]
# Overall we can see that the happiness scores are increasing year over year (other than in 2017). Freedom also seems to have an upward trend year over year other than in 2016 and 2019 where the scores are lower. THe gernosity score seems to be decreasing overall (sharp decreases in 2017 and 2021 but steady otherwise). Trust and family score seem to have an inverse relationship (when trust scores are highest, family scores are lowest and vice versa (other than 2015 anf 2022). The economy score was realtively constant year over year, but significantly increased in 2022. Lastly, life expectancy seems pretty random but was highest in 2019 and lowest in 2021 (COVID).

# %% [markdown]
# In order or score (influence on overall) seems to be...
#
# Economy/Family, Health, Freedom, Generosity, and Trust

# %% [markdown]
# 2015 - China stock market crash, US and cuba restore ties

# %% [markdown]
# 2016 - Russia interference in election, Britain leaves EU, North Korea missile tests, TPP falls,impeachments, failed coups

# %% [markdown]
#
# 2018 - Me too, election fallout (facebook), gun mass shootings, global warming sharp increase

# %% [markdown]
# 2019 - lots of protests against governemnt worldwide in multiple countries

# %% [markdown]
# 2020 - oil price tank, black lives matter, joe biden, COVID

# %% [markdown]
# 2021 - COVID and its fallout
