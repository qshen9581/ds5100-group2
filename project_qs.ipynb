# %%
import pandas as pd
import numpy as np

# %%
data_2015= pd.read_csv("2015.csv")
data_2016= pd.read_csv("2016.csv")
data_2017= pd.read_csv("2017.csv")
data_2018= pd.read_csv("2018.csv")
data_2019= pd.read_csv("2019.csv")

# %%
data_2015["Year"]=2015
data_2016["Year"]=2016
data_2017["Year"]=2017
data_2018["Year"]=2018
data_2019["Year"]=2019

# %%
data_2015.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual  Year
# 0     0.29678            2.51738  2015
# 1     0.43630            2.70201  2015
# 2     0.34139            2.49204  2015

# %%
#data_2015.head()
data_2016.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.44453     0.36171            2.73939  2016
# ...

# %%
data_2017=data_2017.rename(columns={"Happiness.Score":"Happiness Score","Happiness.Rank": "Happiness Rank", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Health..Life.Expectancy.": "Health (Life Expectancy)","Trust..Government.Corruption.":"Trust (Government Corruption)","Dystopia.Residual":"Dystopia Residual"})
data_2017.head(3)
# Out:
#    Country  Happiness Rank  Happiness Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
# 2  Iceland               3            7.504      7.622030     7.385970
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
#
#    Generosity  Trust (Government Corruption)  Dystopia Residual  Year
# 0    0.362012                       0.315964           2.277027  2017
# 1    0.355280                       0.400770           2.313707  2017
# 2    0.475540                       0.153527           2.322715  2017

# %%
data_2018=data_2018.rename(columns={"Social support":"Family","Freedom to make life choices":"Freedom","Score":"Happiness Score","Country or region":"Country","Overall rank": "Happiness Rank", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)","Perceptions of corruption":"Trust (Government Corruption)"})
data_2018.head(3)
# Out:
#    Happiness Rank  Country  Happiness Score  Economy (GDP per Capita)  Family  \
# 0               1  Finland            7.632                     1.305   1.592
# 1               2   Norway            7.594                     1.456   1.582
# 2               3  Denmark            7.555                     1.351   1.590
#
#    Health (Life Expectancy)  Freedom  Generosity  \
# 0                     0.874    0.681       0.202
# 1                     0.861    0.686       0.286
# 2                     0.868    0.683       0.284
#
#    Trust (Government Corruption)  Year
# 0                          0.393  2018
# 1                          0.340  2018
# 2                          0.408  2018

# %%
data_2019=data_2019.rename(columns={"Freedom to make life choices":"Freedom","Social support":"Family","Score":"Happiness Score","Country or region":"Country","Overall rank": "Happiness Rank", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)","Perceptions of corruption":"Trust (Government Corruption)"})
data_2019.head(3)
# Out:
#    Happiness Rank  Country  Happiness Score  Economy (GDP per Capita)  Family  \
# 0               1  Finland            7.769                     1.340   1.587
# 1               2  Denmark            7.600                     1.383   1.573
# 2               3   Norway            7.554                     1.488   1.582
#
#    Health (Life Expectancy)  Freedom  Generosity  \
# 0                     0.986    0.596       0.153
# 1                     0.996    0.592       0.252
# 2                     1.028    0.603       0.271
#
#    Trust (Government Corruption)  Year
# 0                          0.393  2019
# 1                          0.410  2019
# 2                          0.341  2019

# %%
list(data_2015.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
list(data_2016.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Lower Confidence Interval',
#  'Upper Confidence Interval',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
list(data_2017.columns)
# Out:
# ['Country',
#  'Happiness Rank',
#  'Happiness Score',
#  'Whisker.high',
#  'Whisker.low',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Dystopia Residual',
#  'Year']

# %%
list(data_2018.columns)
# Out:
# ['Happiness Rank',
#  'Country',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Year']

# %%
list(data_2019.columns)
# Out:
# ['Happiness Rank',
#  'Country',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Year']

# %%
df_all = data_2015.append([data_2016,data_2017,data_2018,data_2019],ignore_index = True)

# %%
df_all.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data_top = df_all[df_all["Happiness Rank"]<=5]
data_top
# Out:
#          Country          Region  Happiness Rank  Happiness Score  \
# 0    Switzerland  Western Europe               1            7.587
# 1        Iceland  Western Europe               2            7.561
# 2        Denmark  Western Europe               3            7.527
# 3         Norway  Western Europe               4            7.522
# 4         Canada   North America               5            7.427
# 158      Denmark  Western Europe               1            7.526
# 159  Switzerland  Western Europe               2            7.509
# 160      Iceland  Western Europe               3            7.501
# 161       Norway  Western Europe               4            7.498
# 162      Finland  Western Europe               5            7.413
# 315       Norway             NaN               1            7.537
# 316      Denmark             NaN               2            7.522
# 317      Iceland             NaN               3            7.504
# ...

# %% [markdown]
# # Research question:
# Based on the happiness profile, where consistently is the best place to live and why?
#
# # best place retirement, career start/end
#
# # heat map for happiness score by continents
#
# #1 which country has the biggest happiness score and why? (top
#   #  bar chart top five
#
# #2 observe top 5 country over the years, what changed?
#
# #3 How aboub America, what changed in the past years, how to improve America's score
#
#
# #4 some distribution of drivers over the years? (duplicated)
#
#
#
# #additional dataset supplement
#
#
# #visualizaiton
# # top five country each year
# # if there is any movement, what changed.
# # distribution of health over the year
# # distribution of freedom over the year
# # corruption over the year
# # Driver of the
# # How to improve the happiness score
# # Where do you want to live

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### data rename
# ### append data
# ### Any N/A?
# ### dictionary and fill in region?
