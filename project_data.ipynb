# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import the yearly data

# %%
data_2015= pd.read_csv("2015.csv")
data_2016= pd.read_csv("2016.csv")
data_2017= pd.read_csv("2017.csv")
data_2018= pd.read_csv("2018.csv")
data_2019= pd.read_csv("2019.csv")
data_2020= pd.read_csv("2020.csv")
data_2021= pd.read_csv("2021.csv")
data_2022= pd.read_csv("2022.csv")

# %% [markdown]
# ## Add year column before combining them

# %%
data_2015["Year"]=2015
data_2016["Year"]=2016
data_2017["Year"]=2017
data_2018["Year"]=2018
data_2019["Year"]=2019
data_2022["Year"]=2022

# %% [markdown]
# ## Understand the data element and uniform the data before append

# %%
data_2015.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual  Year
# 0     0.29678            2.51738  2015
# 1     0.43630            2.70201  2015
# 2     0.34139            2.49204  2015

# %%
#data_2015.head()
data_2016.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.44453     0.36171            2.73939  2016
# ...

# %%
data_2017=data_2017.rename(columns={"Happiness.Score":"Happiness Score","Happiness.Rank": "Happiness Rank", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Health..Life.Expectancy.": "Health (Life Expectancy)","Trust..Government.Corruption.":"Trust (Government Corruption)","Dystopia.Residual":"Dystopia Residual"})
data_2017.head(3)
# Out:
#    Country          Region  Happiness Rank  Happiness Score  Whisker.high  \
# 0   Norway  Western Europe               1            7.537      7.594445
# 1  Denmark  Western Europe               2            7.522      7.581728
# 2  Iceland  Western Europe               3            7.504      7.622030
#
#    Whisker.low  Economy (GDP per Capita)    Family  Health (Life Expectancy)  \
# 0     7.479556                  1.616463  1.533524                  0.796667
# 1     7.462272                  1.482383  1.551122                  0.792566
# 2     7.385970                  1.480633  1.610574                  0.833552
#
#     Freedom  Generosity  Trust (Government Corruption)  Dystopia Residual  \
# 0  0.635423    0.362012                       0.315964           2.277027
# 1  0.626007    0.355280                       0.400770           2.313707
# 2  0.627163    0.475540                       0.153527           2.322715
#
#    Year
# 0  2017
# 1  2017
# 2  2017

# %%
data_2018=data_2018.rename(columns={"Social support":"Family","Freedom to make life choices":"Freedom","Score":"Happiness Score","Country or region":"Country","Overall rank": "Happiness Rank", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)","Perceptions of corruption":"Trust (Government Corruption)"})
data_2018.head(3)
# Out:
#    Happiness Rank  Country          Region  Happiness Score  \
# 0               1  Finland  Western Europe            7.632
# 1               2   Norway  Western Europe            7.594
# 2               3  Denmark  Western Europe            7.555
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                     1.305   1.592                     0.874    0.681
# 1                     1.456   1.582                     0.861    0.686
# 2                     1.351   1.590                     0.868    0.683
#
#    Generosity  Trust (Government Corruption)  Dystopia Residual  Year
# 0       0.202                          0.393              2.585  2018
# 1       0.286                          0.340              2.383  2018
# 2       0.284                          0.408              2.371  2018

# %%
data_2019=data_2019.rename(columns={"Freedom to make life choices":"Freedom","Social support":"Family","Score":"Happiness Score","Country or region":"Country","Overall rank": "Happiness Rank", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)","Perceptions of corruption":"Trust (Government Corruption)"})
data_2019.head(3)
# Out:
#    Happiness Rank  Country          Region  Happiness Score  \
# 0               1  Finland  Western Europe            7.769
# 1               2  Denmark  Western Europe            7.600
# 2               3   Norway  Western Europe            7.554
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                     1.340   1.587                     0.986    0.596
# 1                     1.383   1.573                     0.996    0.592
# 2                     1.488   1.582                     1.028    0.603
#
#    Generosity  Trust (Government Corruption)  Dystopia Residual  Year
# 0       0.153                          0.393              2.714  2019
# 1       0.252                          0.410              2.394  2019
# 2       0.271                          0.341              2.241  2019

# %%
data_2020.head(3)
list(data_2020.columns)
# Out:
# ['Happiness Rank',
#  'Country',
#  'Region',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Dystopia Residual',
#  'Year']

# %%
data_2021.head(3)
# Out:
#    Happiness Rank      Country          Region  Happiness Score  \
# 0               1      Finland  Western Europe            7.842
# 1               2      Denmark  Western Europe            7.620
# 2               3  Switzerland  Western Europe            7.571
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                     1.446   1.106                     0.741    0.691
# 1                     1.502   1.108                     0.763    0.686
# 2                     1.566   1.079                     0.816    0.653
#
#    Generosity  Trust (Government Corruption)  Dystopia Residual  Year
# 0       0.124                          0.481              3.253  2021
# 1       0.208                          0.485              2.868  2021
# 2       0.204                          0.413              2.839  2021

# %%
list(data_2015.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
list(data_2016.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Lower Confidence Interval',
#  'Upper Confidence Interval',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
list(data_2017.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Whisker.high',
#  'Whisker.low',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Dystopia Residual',
#  'Year']

# %%
list(data_2018.columns)
# Out:
# ['Happiness Rank',
#  'Country',
#  'Region',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Dystopia Residual',
#  'Year']

# %%
list(data_2020.columns)
# Out:
# ['Happiness Rank',
#  'Country',
#  'Region',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Dystopia Residual',
#  'Year']

# %%
data_2022=data_2022.rename(columns={"Happiness score":"Happiness Score","RANK":"Happiness Rank"})
list(data_2022.columns)
# Out:
# ['Happiness Rank',
#  'Country',
#  'Region',
#  'Happiness Score',
#  'Dystopia Residual',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Generosity',
#  'Trust (Government Corruption)',
#  'Year']

# %%
df_all = data_2015.append([data_2016,data_2017,data_2018,data_2019,data_2020,data_2021,data_2022],ignore_index = True)

# %%
df_all.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data2020=df_all[df_all['Year']==2020]
data2020
# Out:
#                       Country              Region  Happiness Rank  \
# 782                   Finland      Western Europe               1
# 783                   Denmark      Western Europe               2
# 784               Switzerland      Western Europe               3
# 785                   Iceland      Western Europe               4
# 786                    Norway      Western Europe               5
# ..                        ...                 ...             ...
# 930  Central African Republic  Sub-Saharan Africa             149
# 931                    Rwanda  Sub-Saharan Africa             150
# 932                  Zimbabwe  Sub-Saharan Africa             151
# 933               South Sudan  Sub-Saharan Africa             152
# 934               Afghanistan          South Asia             153
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)    Family  \
# 782           7.8087             NaN                  1.285190  1.499526
# ...

# %%
df_all[df_all["Trust (Government Corruption)"].isnull()]
# Out:
#                   Country                        Region  Happiness Rank  \
# 489  United Arab Emirates  Middle East and North Africa              20
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)  Family  \
# 489            6.774             NaN                     2.096   0.776
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 489                      0.67    0.284                            NaN
#
#      Generosity  Dystopia Residual  Year  Lower Confidence Interval  \
# 489       0.186              2.762  2018                        NaN
#
#      Upper Confidence Interval  Whisker.high  Whisker.low
# 489                        NaN           NaN          NaN

# %% [markdown]
# ## Creat a clean dataset for future exploration

# %%
df_all.to_csv('data_all.csv')

# %%
data_top = df_all[df_all["Happiness Rank"]<=5]
data_top
# Out:
#           Country          Region  Happiness Rank  Happiness Score  \
# 0     Switzerland  Western Europe               1           7.5870
# 1         Iceland  Western Europe               2           7.5610
# 2         Denmark  Western Europe               3           7.5270
# 3          Norway  Western Europe               4           7.5220
# 4          Canada   North America               5           7.4270
# 158       Denmark  Western Europe               1           7.5260
# 159   Switzerland  Western Europe               2           7.5090
# 160       Iceland  Western Europe               3           7.5010
# 161        Norway  Western Europe               4           7.4980
# 162       Finland  Western Europe               5           7.4130
# 315        Norway  Western Europe               1           7.5370
# 316       Denmark  Western Europe               2           7.5220
# 317       Iceland  Western Europe               3           7.5040
# ...
